# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\91895\\Downloads\\AAPL.csv")

# %%
#!pip install AutoTS

# %%
import matplotlib.pyplot as plt

# %%
df =df[["Date" , "Close"]]
df["Date"] = pd.to_datetime(df.Date)
df["Close"].plot(figsize=(12,8),title="Apple Stock Prices" , fontsize=20, label="Close Price")
plt.legend()
plt.grid()
plt.show()

# %%
from autots import AutoTS
model = AutoTS(forecast_length=10 , frequency='infer',
              ensemble='simple' , drop_data_older_than_periods=200)
model=model.fit(df , date_col='Date' , value_col='Close' , id_col=None)
# Out:
# Data frequency is: B, used frequency is: B
# Old data dropped by `drop_data_older_than_periods`.
# Model Number: 1 with model ARIMA in generation 0 of 10
# Model Number: 2 with model AverageValueNaive in generation 0 of 10
# Model Number: 3 with model AverageValueNaive in generation 0 of 10
# Model Number: 4 with model AverageValueNaive in generation 0 of 10
# Model Number: 5 with model DatepartRegression in generation 0 of 10
# Model Number: 6 with model DatepartRegression in generation 0 of 10
# Model Number: 7 with model DatepartRegression in generation 0 of 10
# C:\Users\91895\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# ...

# %%
prediction = model.predict()
forecast = prediction.forecast
print("Stock Price Prediction of Apple")
print(forecast)
# Out:
# Stock Price Prediction of Apple
#                  Close
# 2021-04-19  134.486358
# 2021-04-20  134.417431
# 2021-04-21  133.450438
# 2021-04-22  133.891101
# 2021-04-23  133.525122
# 2021-04-26  131.015271
# 2021-04-27  131.662094
# 2021-04-28  130.500826
# 2021-04-29  130.473490
# 2021-04-30  130.850867
